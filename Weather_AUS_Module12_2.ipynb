# %% [markdown]
# # Module 12.2 Assignments
#
# Find a dataset you'd like to explore. This can be something you're familiar with or something new. Create a Jupyter notebook and then:
#
#     Choose one variable and plot that variable four different ways.
#     Choose two continuous variables, and plot them three different ways.
#     Choose one continuous variable and one categorical variable, and plot them six different ways.
#     Give the pros and cons of each plot you create. You can use variables from multiple datasets if you like.

# %%
#Import libraries necessary for a suite of data analyses.
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib import rcParams
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import numpy as np
import scipy as sp
from scipy import stats
from scipy.stats import ttest_ind
import os
import datetime
from datetime import datetime
from pandas.plotting import register_matplotlib_converters

# %%
#Load data from local computer.
weather = pd.read_csv('/home/vanellope/Documents/Thinkful/weather_australia/weatherAUS.csv')
display(weather)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
#Review the variables in the dataframe, including their data types.
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %%
#Convert time format from object to datetime.
weather['Date_f'] = pd.to_datetime(weather['Date'], format='%Y-%m-%d')
weather['month'] = weather['Date_f'].dt.month
weather['year'] = weather['Date_f'].dt.year
print(weather.info()) #Check to see if object-to-datetime change worked.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 27 columns):
# Date             142193 non-null object
# Location         142193 non-null object
# MinTemp          141556 non-null float64
# MaxTemp          141871 non-null float64
# Rainfall         140787 non-null float64
# Evaporation      81350 non-null float64
# Sunshine         74377 non-null float64
# WindGustDir      132863 non-null object
# WindGustSpeed    132923 non-null float64
# WindDir9am       132180 non-null object
# WindDir3pm       138415 non-null object
# WindSpeed9am     140845 non-null float64
# WindSpeed3pm     139563 non-null float64
# Humidity9am      140419 non-null float64
# Humidity3pm      138583 non-null float64
# Pressure9am      128179 non-null float64
# Pressure3pm      128212 non-null float64
# Cloud9am         88536 non-null float64
# Cloud3pm         85099 non-null float64
# Temp9am          141289 non-null float64
# ...

# %%
#Check the values of the variable 'Location' and the total number of values.
print(weather['Location'].unique())
len(weather['Location'].unique().tolist())
# Out:
# ['Albury' 'BadgerysCreek' 'Cobar' 'CoffsHarbour' 'Moree' 'Newcastle'
#  'NorahHead' 'NorfolkIsland' 'Penrith' 'Richmond' 'Sydney' 'SydneyAirport'
#  'WaggaWagga' 'Williamtown' 'Wollongong' 'Canberra' 'Tuggeranong'
#  'MountGinini' 'Ballarat' 'Bendigo' 'Sale' 'MelbourneAirport' 'Melbourne'
#  'Mildura' 'Nhil' 'Portland' 'Watsonia' 'Dartmoor' 'Brisbane' 'Cairns'
#  'GoldCoast' 'Townsville' 'Adelaide' 'MountGambier' 'Nuriootpa' 'Woomera'
#  'Albany' 'Witchcliffe' 'PearceRAAF' 'PerthAirport' 'Perth' 'SalmonGums'
#  'Walpole' 'Hobart' 'Launceston' 'AliceSprings' 'Darwin' 'Katherine'
#  'Uluru']
# 49

# %%
#Pick a single value of 'Location' for further review, along with a subset of variables to explore.
sub_weather = weather.loc[weather['Location'] == 'Sydney',  ['Date_f', 'month', 'year','MinTemp', 'MaxTemp', 'Rainfall']]
display(sub_weather)
# Out:
#           Date_f  month  year  MinTemp  MaxTemp  Rainfall
# 29497 2008-02-01      2  2008     19.5     22.4      15.6
# 29498 2008-02-02      2  2008     19.5     25.6       6.0
# 29499 2008-02-03      2  2008     21.6     24.5       6.6
# 29500 2008-02-04      2  2008     20.2     22.8      18.8
# 29501 2008-02-05      2  2008     19.7     25.7      77.4
# 29502 2008-02-06      2  2008     20.2     27.2       1.6
# 29503 2008-02-07      2  2008     18.6     26.3       6.2
# 29504 2008-02-08      2  2008     17.2     22.3      27.6
# 29505 2008-02-09      2  2008     16.4     20.8      12.6
# 29506 2008-02-10      2  2008     14.6     24.2       8.8
# 29507 2008-02-11      2  2008     16.4     23.9       0.0
# 29508 2008-02-12      2  2008     18.9     27.3       0.0
# 29509 2008-02-13      2  2008     18.4     22.8      14.4
# 29510 2008-02-14      2  2008     16.9     24.3       3.0
# 29511 2008-02-15      2  2008     18.3     24.4       0.0
# ...

# %%
# Plot MaxTemp by date

sns.set_palette("husl") #Choose color pallette.
plt.figure(figsize=(18,6)) #Make figure size wide to better see the data. This line didn't work when put below the lineplot code.
g = sns.lineplot(x="Date_f", y="MaxTemp", data=sub_weather) #Choose lineplot for 'MaxTemp', which is a continuous variable.

plt.ylabel('Maximum Daily Temperature (Celsius)') #Change the labels of the axes to make them more explanatory.
plt.xlabel('Date')
plt.title('Daily Maximum Temperature in Sydney, Australia')

#Annotate figure.
# Out:
# /home/vanellope/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Daily Maximum Temperature in Sydney, Australia')

# %%
# Plot MaxTemp by date

sns.set_palette("husl") #Choose color pallette.
plt.figure(figsize=(18,6))#Removing this line of code doesn't solve the x-axis problem.
fig, ax = sns.scatterplot(x="Date_f", y="MaxTemp", data=sub_weather)
plt.ylabel('Maximum Daily Temperature (Celsius)') #Change the labels of the axes to make them more explanatory.
plt.xlabel('Date')
plt.xlim(datetime.date(2008, 1, 1), datetime.date(2018, 1, 1))
plt.title('Daily Maximum Temperature in Sydney, Australia')
plt.xticks(rotation='vertical')

#print(ax.get_xlim())

#Add figure title.
#Annotate figure.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4b0c1be1b463> in <module>
#       3 sns.set_palette("husl") #Choose color pallette.
#       4 plt.figure(figsize=(18,6))#Removing this line of code doesn't solve the x-axis problem.
# ----> 5 fig, ax = sns.scatterplot(x="Date_f", y="MaxTemp", data=sub_weather)
#       6 plt.ylabel('Maximum Daily Temperature (Celsius)') #Change the labels of the axes to make them more explanatory.
#       7 plt.xlabel('Date')
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
#Relplot with hue=city, month=x-axis
#first need to extract month from date and populate new "month" column.


sns.set(style="white")
plt.figure(figsize=(18,6))#Removing this line of code doesn't solve the x-axis problem. It also doesn't appear to work.
# Plot miles per gallon against horsepower with other semantics
h=sns.relplot(x="Date_f", y="MaxTemp", hue="Location", alpha=0.5, data=weather)
plt.xticks(rotation='vertical')
# Out:
# (array([729390.0000026, 730120.0000026, 730851.0000026, 731581.0000026,
#         732312.0000026, 733042.0000026, 733773.0000026, 734503.0000026,
#         735234.0000026, 735964.0000026, 736695.0000026]),
#  <a list of 11 Text xticklabel objects>)
